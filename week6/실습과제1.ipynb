# %% [markdown]
# <a href="https://colab.research.google.com/github/realcommang/BigDataProcess/blob/main/week6/%EC%8B%A4%EC%8A%B5%EA%B3%BC%EC%A0%9C1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import numpy as np
import tensorflow as tf

np.random.seed(3)
tf.random.set_seed(3)

Data_set = np.loadtxt("/content/drive/MyDrive/deeplearning/080228-master/080228-master/deeplearning/dataset/ThoraricSurgery.csv", delimiter=",")

X = Data_set[:, 0:17]
Y = Data_set[:, 17]

#앞부분 5개의 행들을 추출함
test_X = X[:5, :]
test_Y = Y[:5]

model = Sequential()
model.add(Dense(30, input_dim=17, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

#epochs 옵션과 batch_size 값 증가
model.fit(X, Y, epochs=100, batch_size=10)
#model.fit(X, Y, epochs=1000, batch_size=10)
#model.fit(X, Y, epochs=100, batch_size=100)
#model.fit(X, Y, epochs=1000, batch_size=100)

#model.predict 함수 사용
predictions = model.predict(test_X)
print("Actual Class:" + str(test_Y))
print("Predict Class: ")
print(predictions)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 1s 2ms/step - loss: 7.0414 - accuracy: 0.5170
# Epoch 2/100
# 47/47 [==============================] - 0s 2ms/step - loss: 1.8472 - accuracy: 0.7064
# Epoch 3/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.7263 - accuracy: 0.7638
# Epoch 4/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5861 - accuracy: 0.8234
# Epoch 5/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.5146 - accuracy: 0.8383
# Epoch 6/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4901 - accuracy: 0.8298
# Epoch 7/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4965 - accuracy: 0.8362
# Epoch 8/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4925 - accuracy: 0.8362
# Epoch 9/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4389 - accuracy: 0.8489
# Epoch 10/100
# ...
